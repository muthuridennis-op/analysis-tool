# %%
import pandas as pd
import yfinance as yf

# %%
#retrieving the balance sheet of nvda
nvda= yf.Ticker("NVDA")
balance_sheet=nvda.balance_sheet
for col in balance_sheet.columns:
    if "2025-01-31" in str(col):
        print(balance_sheet[col])
# Out:
# Ordinary Shares Number                              2.447700e+10
# Share Issued                                        2.447700e+10
# Net Debt                                                     NaN
# Total Debt                                          9.982000e+09
# Tangible Book Value                                 7.333200e+10
#                                                         ...
# Receivables                                         2.306500e+10
# Accounts Receivable                                 2.306500e+10
# Cash Cash Equivalents And Short Term Investments    4.321000e+10
# Other Short Term Investments                        3.462100e+10
# Cash And Cash Equivalents                           8.589000e+09
# Name: 2025-01-31 00:00:00, Length: 79, dtype: float64
